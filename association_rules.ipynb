# %%
import numpy as np
import math
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.neighbors import NearestNeighbors
from collections import Counter
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv('MBA.csv')

# %%
df = df.replace(1, True)

# %%
df = df.replace(0, False)

# %%
df
# Out:
#         DVD с записью  DVD/Blu-Ray плееры и компоненты  Hi-Fi компоненты  \
# 0               False                            False             False
# 1               False                            False             False
# 2               False                            False             False
# 3               False                            False             False
# 4               False                            False             False
# ...               ...                              ...               ...
# 132204          False                            False             False
# 132205          False                            False             False
# 132206          False                            False             False
# 132207          False                            False             False
# 132208          False                            False             False
#
#         Автоакустика  Автоаудио  Автокосметика и автохимия  Автомагнитолы  \
# ...

# %%
frequent_itemsets = fpgrowth(dfhelp, min_support=0.001, use_colnames=True)

# %%
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.051945                                  (Детская комната)
# 1   0.249501                           (Прогулки и путешествие)
# 2   0.022082                                         (Наушники)
# 3   0.104543                                          (Игрушки)
# 4   0.013811                               (Аксессуары детство)
# ..       ...                                                ...
# 73  0.001263  (Аксессуары для комп./ноутбуков/принтеров, При...
# 74  0.001385               (Приготовление пищи, Телевизоры LCD)
# 75  0.001874  (Аксессуары для бытовой техники, Приготовление...
# 76  0.001141                  (Инструменты, Приготовление пищи)
# 77  0.002078  (Планшеты, Аксессуары для смартфонов и планшетов)
#
# [78 rows x 2 columns]

# %%
assr = association_rules(frequent_itemsets, min_threshold=0.001)
assr.to_excel('assr.xlsx')
assr
# Out:
#                                    antecedents  \
# 0                            (Детская комната)
# 1                     (Прогулки и путешествие)
# 2                            (Детская комната)
# 3                                    (Игрушки)
# 4                                    (Игрушки)
# 5                     (Прогулки и путешествие)
# 6                         (Аксессуары детство)
# 7                     (Прогулки и путешествие)
# 8                              (Уход за домом)
# 9             (Аксессуары для бытовой техники)
# 10                 (Силовая и садовая техника)
# 11                               (Инструменты)
# 12                        (Приготовление пищи)
# 13                            (Электропитание)
# 14     (Аксессуары для смартфонов и планшетов)
# 15                  (Мобильные средства связи)
# 16                       (Носители информации)
# 17                  (Мобильные средства связи)
# 18                       (Носители информации)
# ...

# %% [markdown]
# #### - support(A->C) = support(A+C), range: [0, 1]
#
# ####  - confidence(A->C) = support(A+C) / support(A), range: [0, 1]
#
# ####  - lift(A->C) = confidence(A->C) / support(C), range: [0, inf]
#
# ####  - leverage(A->C) = support(A->C) - support(A)*support(C), range: [-1, 1]
#
# ####  - conviction = [1 - support(C)] / [1 - confidence(A->C)], range: [0, inf]
